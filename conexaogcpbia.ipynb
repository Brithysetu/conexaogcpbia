# %% [markdown]
# <a href="https://colab.research.google.com/github/Brithysetu/conexaogcpbia/blob/main/conexaogcpbia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importar da biblioteca do pandas e dando um apelido = pd
import pandas as pd
#ler um arquivo .csv
df= pd.read_csv("https://storage.googleapis.com/bucket-analise_de_dados_brithy/dfs_brutos/alunos_matriculados_auladedados.csv")
#exibir via display o csv(df)
df
df
# Out:
#    matricula               nome  idade          cidade    pais  \
# 0       1001         João Silva     29       São Paulo  Brasil
# 1       1002     Maria Oliveira     34  Rio de Janeiro  Brasil
# 2       1003       Pedro Santos     22  Belo Horizonte  Brasil
# 3       1004          Ana Costa     27        Salvador  Brasil
# 4       1005     Carlos Pereira     31       Fortaleza  Brasil
# 5       1006    Laura Rodrigues     25        Curitiba  Brasil
# 6       1007      Bruno Almeida     28    Porto Alegre  Brasil
# 7       1009    Felipe Oliveira     40        Brasília  Brasil
# 8       1010  Juliana Fernandes     26        Campinas  Brasil
#
#                          email      departamento                cargo  salario
# 0         joao.silva@email.com  Recursos Humanos             Analista     4500
# 1     maria.oliveira@email.com        Financeiro         Coordenadora     6200
# 2       pedro.santos@email.com                TI        Desenvolvedor     3500
# ...

# %%
df.shape
# Out:
# (9, 9)

# %%
#tail pega as linhas finais
#se colocar um valor dentro do parenteses exemplo (3), ele lê as 3 ultimas
#se não colocar, ele retorna as 5 ultimas por padrão
df.tail()
# Out:
#    matricula               nome  idade        cidade    pais  \
# 4       1005     Carlos Pereira     31     Fortaleza  Brasil
# 5       1006    Laura Rodrigues     25      Curitiba  Brasil
# 6       1007      Bruno Almeida     28  Porto Alegre  Brasil
# 7       1009    Felipe Oliveira     40      Brasília  Brasil
# 8       1010  Juliana Fernandes     26      Campinas  Brasil
#
#                          email      departamento                cargo  salario
# 4     carlos.pereira@email.com         Logística           Supervisor     5000
# 5    laura.rodrigues@email.com  Recursos Humanos           Assistente     3800
# 6      bruno.almeida@email.com        Financeiro             Analista     4700
# 7    felipe.oliveira@email.com                TI  Gerente de Projetos     7000
# 8  juliana.fernandes@email.com         Logística             Analista     4200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   matricula     9 non-null      int64
#  1   nome          9 non-null      object
#  2   idade         9 non-null      int64
#  3   cidade        9 non-null      object
#  4   pais          9 non-null      object
#  5   email         9 non-null      object
#  6   departamento  9 non-null      object
#  7   cargo         9 non-null      object
#  8   salario       9 non-null      int64
# dtypes: int64(3), object(6)
# memory usage: 776.0+ bytes

# %%
df.columns
# Out:
# Index(['matricula', 'nome', 'idade', 'cidade', 'pais', 'email', 'departamento',
#        'cargo', 'salario'],
#       dtype='object')

# %%
df.nome
# Out:
# 0           João Silva
# 1       Maria Oliveira
# 2         Pedro Santos
# 3            Ana Costa
# 4       Carlos Pereira
# 5      Laura Rodrigues
# 6        Bruno Almeida
# 7      Felipe Oliveira
# 8    Juliana Fernandes
# Name: nome, dtype: object

# %%
df.nome.describe()
# Out:
# count              9
# unique             9
# top       João Silva
# freq               1
# Name: nome, dtype: object

# %%
df.head()
# Out:
#    matricula            nome  idade          cidade    pais  \
# 0       1001      João Silva     29       São Paulo  Brasil
# 1       1002  Maria Oliveira     34  Rio de Janeiro  Brasil
# 2       1003    Pedro Santos     22  Belo Horizonte  Brasil
# 3       1004       Ana Costa     27        Salvador  Brasil
# 4       1005  Carlos Pereira     31       Fortaleza  Brasil
#
#                       email      departamento          cargo  salario
# 0      joao.silva@email.com  Recursos Humanos       Analista     4500
# 1  maria.oliveira@email.com        Financeiro   Coordenadora     6200
# 2    pedro.santos@email.com                TI  Desenvolvedor     3500
# 3       ana.costa@email.com         Marketing     Assistente     4000
# 4  carlos.pereira@email.com         Logística     Supervisor     5000

# %%
df.salario.max()
# Out:
# 7000

# %%
df.salario.median()
# Out:
# 4500.0

# %%
df.salario.min()
# Out:
# 3500

# %%
# criar um coluna de times para cada linha um valor
df["time"]= [
     "Corinthias","Flamengo","Santos",
     "Fluminense", "São Paulo", "Bahia",
     "Vasco", "Palmeiras", "Fortaleza"
]

# %%
df.shape
# Out:
# (9, 10)

# %%
df
# Out:
#    matricula               nome  idade          cidade    pais  \
# 0       1001         João Silva     29       São Paulo  Brasil
# 1       1002     Maria Oliveira     34  Rio de Janeiro  Brasil
# 2       1003       Pedro Santos     22  Belo Horizonte  Brasil
# 3       1004          Ana Costa     27        Salvador  Brasil
# 4       1005     Carlos Pereira     31       Fortaleza  Brasil
# 5       1006    Laura Rodrigues     25        Curitiba  Brasil
# 6       1007      Bruno Almeida     28    Porto Alegre  Brasil
# 7       1009    Felipe Oliveira     40        Brasília  Brasil
# 8       1010  Juliana Fernandes     26        Campinas  Brasil
#
#                          email      departamento                cargo  \
# 0         joao.silva@email.com  Recursos Humanos             Analista
# 1     maria.oliveira@email.com        Financeiro         Coordenadora
# 2       pedro.santos@email.com                TI        Desenvolvedor
# ...

# %%
#gerar um novo csv, sem os valores de index
df.to_csv("Alunos_matriculados_tratados.csv", index=False)

# %%
df["Endereço"]= [
     "Rua A do Br","Rua B do Br","Rua C do Br",
     "Rua D do Br", "Rua E do Br", "Rua F do Br",
     "Rua G do Br", "Rua H do Br", "Rua I do Br"
]

# %%
df["DDD"]= [
     "21","21","21",
     "21", "21", "21",
     "21", "21", "21"
]

# %%
df["Telefone"]= [
     "9874-6541","4568-6325","9632-5698",
     "9874-6598", "9658-9547", "9123-5689",
     "9365-6566", "9258-6748", "94588-699"
]

# %%
df
# Out:
#    matricula               nome  idade          cidade    pais  \
# 0       1001         João Silva     29       São Paulo  Brasil
# 1       1002     Maria Oliveira     34  Rio de Janeiro  Brasil
# 2       1003       Pedro Santos     22  Belo Horizonte  Brasil
# 3       1004          Ana Costa     27        Salvador  Brasil
# 4       1005     Carlos Pereira     31       Fortaleza  Brasil
# 5       1006    Laura Rodrigues     25        Curitiba  Brasil
# 6       1007      Bruno Almeida     28    Porto Alegre  Brasil
# 7       1009    Felipe Oliveira     40        Brasília  Brasil
# 8       1010  Juliana Fernandes     26        Campinas  Brasil
#
#                          email      departamento                cargo  \
# 0         joao.silva@email.com  Recursos Humanos             Analista
# 1     maria.oliveira@email.com        Financeiro         Coordenadora
# 2       pedro.santos@email.com                TI        Desenvolvedor
# ...

# %%
df.to_csv("Alunos_tratados_atualizado.csv", index=False)

# %%
df.DDD
# Out:
# 0    21
# 1    21
# 2    21
# 3    21
# 4    21
# 5    21
# 6    21
# 7    21
# 8    21
# Name: DDD, dtype: object

# %%
df.Telefone
# Out:
# 0    9874-6541
# 1    4568-6325
# 2    9632-5698
# 3    9874-6598
# 4    9658-9547
# 5    9123-5689
# 6    9365-6566
# 7    9258-6748
# 8    94588-699
# Name: Telefone, dtype: object

# %%
df.Endereço
# Out:
# 0    Rua A do Br
# 1    Rua B do Br
# 2    Rua C do Br
# 3    Rua D do Br
# 4    Rua E do Br
# 5    Rua F do Br
# 6    Rua G do Br
# 7    Rua H do Br
# 8    Rua I do Br
# Name: Endereço, dtype: object

# %%
#Um conjunto de listas que irao formar meu dicionario
#os dados serao relacionados a area saude
#Nome,cpf,peso,altura
nomes = [""]

# %%
nomes = ["ANDRE SILVA",
         "AUTO ESCOLA",
         "FONSECA LTDA",
         "ERICK BARRETO",
         "FILIPE MONTEIRO",
         "JAIRO SILVERIO",
         "KELLI MACEDO",
         "MARCELO FERNANDES",
         "MARCO QUEIROZ",
"PATRICK NASCIMENTO"

]
cpfs = [
    '76291539454', '86469405517', '86469405517', '72420026560', '85575821455',
    '86664488906', '62591129398', '62591129398', '55285198020', '88186386378'
]
pesos = [
    50.7, 60.5, 56.7, 77.6, 86.8, 78.6, 67.6, 57.4, 55.9, 66.8
]
alturas = [
    1.80, 1.57, 1.60, 1.61, 1.77, 1.76, 1.88, 1.46, 1.54, 1.59
]
# montamos o dicionario de valores
dicionario_pessoas = {
    'nome': nomes,
    'cpf': cpfs,
    'peso': pesos,
    'altura': alturas
}
# criar um DataFrame pd.DataFrame(aquilo que vc quer que vire um DataFrame)
df_pessoas = pd.DataFrame(dicionario_pessoas)
display(df_pessoas)
# Out:
#                  nome          cpf  peso  altura
# 0         ANDRE SILVA  76291539454  50.7    1.80
# 1         AUTO ESCOLA  86469405517  60.5    1.57
# 2        FONSECA LTDA  86469405517  56.7    1.60
# 3       ERICK BARRETO  72420026560  77.6    1.61
# 4     FILIPE MONTEIRO  85575821455  86.8    1.77
# 5      JAIRO SILVERIO  86664488906  78.6    1.76
# 6        KELLI MACEDO  62591129398  67.6    1.88
# 7   MARCELO FERNANDES  62591129398  57.4    1.46
# 8       MARCO QUEIROZ  55285198020  55.9    1.54
# 9  PATRICK NASCIMENTO  88186386378  66.8    1.59

# %%
# 3 primeira
df_pessoas.head(3)
# Out:
#            nome          cpf  peso  altura
# 0   ANDRE SILVA  76291539454  50.7    1.80
# 1   AUTO ESCOLA  86469405517  60.5    1.57
# 2  FONSECA LTDA  86469405517  56.7    1.60

# %%
# 6 ultimas
df_pessoas.tail(6)
# Out:
#                  nome          cpf  peso  altura
# 4     FILIPE MONTEIRO  85575821455  86.8    1.77
# 5      JAIRO SILVERIO  86664488906  78.6    1.76
# 6        KELLI MACEDO  62591129398  67.6    1.88
# 7   MARCELO FERNANDES  62591129398  57.4    1.46
# 8       MARCO QUEIROZ  55285198020  55.9    1.54
# 9  PATRICK NASCIMENTO  88186386378  66.8    1.59

# %%
# 3 quantas linhas e colunas
df_pessoas.shape
# Out:
# (10, 4)

# %%
# exibe dados sobre o dataframe colunas, quantidade de linhas, numero de indices,
# tipos de dados de colunas....
df_pessoas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nome    10 non-null     object
#  1   cpf     10 non-null     object
#  2   peso    10 non-null     float64
#  3   altura  10 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 448.0+ bytes

# %%
# criar um csv para guardar em um storage
# to_csv

df_pessoas.to_csv('clientes_daempresa.csv', index=False)
# jogar no storage e torna público

# %%
import pandas as pd
#ler um arquivo .csv
df2= pd.read_csv("https://storage.googleapis.com/bucket-analise_de_dados_brithy/dfs_brutos/clientes_daempresa.csv")
df2
# Out:
#                  nome          cpf  peso  altura
# 0         ANDRE SILVA  76291539454  50.7    1.80
# 1         AUTO ESCOLA  86469405517  60.5    1.57
# 2        FONSECA LTDA  86469405517  56.7    1.60
# 3       ERICK BARRETO  72420026560  77.6    1.61
# 4     FILIPE MONTEIRO  85575821455  86.8    1.77
# 5      JAIRO SILVERIO  86664488906  78.6    1.76
# 6        KELLI MACEDO  62591129398  67.6    1.88
# 7   MARCELO FERNANDES  62591129398  57.4    1.46
# 8       MARCO QUEIROZ  55285198020  55.9    1.54
# 9  PATRICK NASCIMENTO  88186386378  66.8    1.59

# %%
#TRATAMENTO
#Criar uma coluna chamada imc, para efetuar o calculo do peso /altura**altura)

# %%
df2["peso"]
# Out:
# 0    50.7
# 1    60.5
# 2    56.7
# 3    77.6
# 4    86.8
# 5    78.6
# 6    67.6
# 7    57.4
# 8    55.9
# 9    66.8
# Name: peso, dtype: float64

# %%
df2["altura"]
# Out:
# 0    1.80
# 1    1.57
# 2    1.60
# 3    1.61
# 4    1.77
# 5    1.76
# 6    1.88
# 7    1.46
# 8    1.54
# 9    1.59
# Name: altura, dtype: float64

# %%
df2["imc"]= round(

                  df2["peso"]/(df2["altura"] ** 2),
                  2
)
df2
# Out:
#                  nome          cpf  peso  altura    Imc    imc
# 0         ANDRE SILVA  76291539454  50.7    1.80  15.65  15.65
# 1         AUTO ESCOLA  86469405517  60.5    1.57  24.54  24.54
# 2        FONSECA LTDA  86469405517  56.7    1.60  22.15  22.15
# 3       ERICK BARRETO  72420026560  77.6    1.61  29.94  29.94
# 4     FILIPE MONTEIRO  85575821455  86.8    1.77  27.71  27.71
# 5      JAIRO SILVERIO  86664488906  78.6    1.76  25.37  25.37
# 6        KELLI MACEDO  62591129398  67.6    1.88  19.13  19.13
# 7   MARCELO FERNANDES  62591129398  57.4    1.46  26.93  26.93
# 8       MARCO QUEIROZ  55285198020  55.9    1.54  23.57  23.57
# 9  PATRICK NASCIMENTO  88186386378  66.8    1.59  26.42  26.42

# %%
df2 = df2.drop("Imc",axis=1)

# %%
df2
# Out:
#                  nome          cpf  peso  altura    imc
# 0         ANDRE SILVA  76291539454  50.7    1.80  15.65
# 1         AUTO ESCOLA  86469405517  60.5    1.57  24.54
# 2        FONSECA LTDA  86469405517  56.7    1.60  22.15
# 3       ERICK BARRETO  72420026560  77.6    1.61  29.94
# 4     FILIPE MONTEIRO  85575821455  86.8    1.77  27.71
# 5      JAIRO SILVERIO  86664488906  78.6    1.76  25.37
# 6        KELLI MACEDO  62591129398  67.6    1.88  19.13
# 7   MARCELO FERNANDES  62591129398  57.4    1.46  26.93
# 8       MARCO QUEIROZ  55285198020  55.9    1.54  23.57
# 9  PATRICK NASCIMENTO  88186386378  66.8    1.59  26.42

# %%
#criar o csv tratado
df2.to_csv("clientes_daempresa_tratados.csv", index=False)

# %%
num = 100 == 100
num
# Out:
# True
